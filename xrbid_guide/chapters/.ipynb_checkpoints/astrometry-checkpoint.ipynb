# %% [markdown]
# (chap:astrometry)=
# # Astrometric Corrections
#
# Because we are combining the data from two different instruments, there are corrections that must be made to the coordinates of the X-ray sources such that it is propely in line with the coordinate system of *HST*. There will be some intrinsic amount of uncertainty in the XRBs' coordinates due to the differences in the X-ray and optical resolution of their respective instruments. These are accounted for by defining 1- and 2-$\sigma$ regions around each XRB, which trace out the regions within which we are 68% and 95% sure that the source falls. These regions are calculated using the information obtained through the astrometric correction process --- namely, the standard deviation of the median offset between optical and X-ray coordinates. This Chapter outlines how to conduct an astrometric correction and calculate the 1- and 2-$\sigma$ positional uncertainty regions around each XRB.
#
# ## Calibrator Selection
# To calibrate between X-ray and optical source coordinates, we need to select a sample of optical sources that we are reasonably certain are producing the X-ray emissions we detect. These include background galaxies (AGN and quasars), foreground stars, and isolated globular clusters (for example, {numref}`fig-astrometric-calibrators`). To find these sources, we must plot the coordinates of each X-ray source onto the *HST* image. We then identify the X-ray sources and their optical counterparts that are best suited for the assessment. You will want to pull the coordinates for each selected X-ray source, and (if you choose to do a by-hand correction) their associated optical source.
#
# ```{figure} ../images/astrometric_calibrators.png
# :name: fig-astrometric-calibrators
# :width: 750px
#
# Examples of X-ray sources that can be used as calibrators for the astrometric correction. The first 3 images are of AGN and quasars, based on their shapes and/or extremely red colors. The 4th is a foreground star, identifiable by the diffraction spikes. The last is a (somewhat) isolated globular cluster, based on the shape, color, and size relative to typical stars in M101.
# ```
#
# ## Correction Calculation and Application
# As you may have guessed, I've written a function that will calculate the astrometric corrections automatically, called `CorrectAstrometry`. It takes in the coordinates of your selected X-ray sources (`cat_coords`) and finds the nearest optical source from the coordinates of some base catalog (`base_coords`, which in this case are the coordinates from the `DAOStarFinder` catalog from {ref}`sec:runphots`). Alternatively, you can calculate the astrometric correction yourself by hand-selecting the best optical source position of each calibrator and finding the median x- and y-coordinate offset between the optical and X-ray positions, as well as the standard deviation of those offsets.
#
# If the standard deviations on the offsets are larger than the median offsets, then that suggests the *CXO* sources are already well-aligned with the *HST* image and no coordinate shift is necessary. The standard deviations on those shifts, however, are still needed to calculate the positional uncertainties, as it represents the variations in where the optical counterparts fall with respect to the X-ray coordinates of the selected sources. Ideally these will be small, but they're expected to be non-zero.
#
# Below is the code I use to find the X-ray calibrators and call `CorrectAstrometry` to calculate the correction:

# %%
import os
cd = os.chdir
pwd = os.getcwd

from XRBID.Sources import LoadSources, GetCoords
from XRBID.WriteScript import WriteReg
from XRBID.DataFrameMod import RemoveElse, FindUnique
from XRBID.Align import CorrectAstrometry

# Reading in sources from the DataFrame containing all of the X-ray sources
# You can use pd.read_csv() instead of LoadSources, if you prefer
M101_CSC = LoadSources("../testdatacscresults_M101.frame")

# Find X-ray sources with a unique CSC ID,
# in case multiple rows in the the DataFrame have the same CSC ID
M101_unique = FindUnique(M101_CSC, header="CSC ID")

# Saving M101 to a region file that can be opened in DS9
WriteReg(M101_unique, outfile="M101_cscsources.reg", idname="CSC ID", radius=50, width=2, 
         color="hotpink", showlabel=True)
# Out:
# Reading in sources from cscresults_M101.frame...
# Saving M101_cscsources.reg

# %% [markdown]
# The code above reads in the `DataFrame` (CSV) file containing the X-ray sources (created in {ref}`sec:csc-dataframe`) and saves a region file of these sources called `M101_cscsources.reg`. Open whatever image you want to align these sources to in `DS9` (I use the F555W mosaic file created in {ref}`sec:astrodrizzle`) with `Region > Open`. Then, inspect the image to select a handful of good astrometric calibrator sources (see {numref}`fig-astrometric-calibrators`).

# %%
# List of source names to use as calibrators in the Astrometric Correction
# These I identified manually by inspecting the HST image in DS9 with the 
# regions saved above plotted over the image
M101_calibrators = ['2CXO J140251.0+542420', 
                    '2CXO J140248.0+542403', 
                    '2CXO J140356.0+542057',
                    '2CXO J140355.8+542058',
                    '2CXO J140357.6+541856',
                    '2CXO J140339.3+541827',
                    '2CXO J140346.1+541615',
                    '2CXO J140253.3+541855',
                    '2CXO J140252.1+541946']

print(len(M101_calibrators), "calibrators to match...")

# Using DataFrameMod.RemoveElse() to remove all but the sources above from the DataFrame
M101_calibrators = RemoveElse(M101_unique, keep=M101_calibrators, header="CSC ID")
print(len(M101_calibrators), "calibrators found.")

# Saving these as a region file, in case we want to double-check
WriteReg(M101_calibrators, outfile="M101_calibrators", radius=25, width=2)
# Out:
# 9 calibrators to match...
# 9 calibrators found.
# Saving M101_calibrators.reg

# %% [markdown]
# The catalog coordinates you'll want to use are the coordiates of the calibrators, while the base coordinates you're aligning them to come from the source extraction conducted in {ref}`sec:runphots`. Make sure you're using the same coordinate system for both lists (in my case, I'm using the galaxy coordiates, which are designated `fk5` in `DS9`. Thus, I pull the base coordinates from `M101_daofind_f555w_acs_fk5.reg`).

# %% [markdown]
# ```
# # Setting up the base and the catalog coordinates for CorrectAstrometry
# base_coords = GetCoords("testdata/M101_daofind_f555w_acs_fk5.reg")
# cat_coords = [M101_calibrators["RA"].values.tolist(),
#               M101_calibrators["Dec"].values.tolist()]
#
# # Running CorrectAstrometry
# CorrectAstrometry(base_coords, cat_coords, returnshifts=True, \
#                   savebasereg="testdata/M101_astrocorrect.reg")
# ```

# %% [markdown]
# ```{figure} ../images/astrocorrect-1.png
# :width: 550px
# ```
# ```{figure} ../images/astrocorrect-2.png
# :width: 550px
# ```
# ```{figure} ../images/astrocorrect-3.png
# :width: 550px
# ```

# %% [markdown]
# Here we see that the median x and y shifts are smaller than their standard deviation. This means the alignment is already pretty good, and that we just need to use the standard deviations to calculate the positional uncertainty radii! Otherwise, you will want to take the median shifts and apply this astrometric correction to the coordinates of your X-ray catalog. *`CorrectAstrometry` will not do this for you!*

# %% [markdown]
# (sec:calcPU)=
# ## Calculating Positional Uncertainty
#
# Because of different instrumental resolutions and inherent uncertainties, it isn't possible to know the *exact* location of an X-ray source on the *HST* optical image, but the positional uncertainty defines a region within which we are reasonably certain the X-ray source falls. This is defined by 1- and 2-$\sigma$ radii, representing the region within which the source has a 68% and 95% chance of being found.
#
# There are two components that go in to the positional uncertainty estimation: the X-ray positional uncertainty, and the standard deviation on the astrometric correction above. The X-ray positional uncertainty is due to the fact that the PSF of *CXO* increasingly degrades for sources that are an increasing distance from the telescope's main pointing at the time of the observation. That is, the farther the X-ray source is from the center of the image, the harder it is to tell where those detected X-rays came from.
#
# The X-ray positional uncertainty is obtained using Equations 12 and 14 from {cite:p}`kim07`:
#
# ```{figure} ../images/kim07_pu.png
# :width: 600px
# ```
#
# The source counts and the off-axis angle are `src_cnts_aper_b` and `theta` or `theta_mean` from {ref}`chap:csc-data`, which I renamed `Counts` and `Theta` in my `DataFrame`.
#
# The positional uncertainties from the standard deviations are added in quadrature to the X-ray uncertainties, meaning you sum the squares of the uncertainties and take the square root. So for 1- and 2-$\sigma$, you'd combine the positional uncertainties from the equations above (let's call them `sig1_kim` and `sig2_kim`) with those from the standard deviations on the astrometric correction (`xstd` and `ystd`) thus:
#
# ```
# from numpy import sqrt
#
# sig_astro = sqrt(xstd**2 + ystd**2)
# sig1 = sqrt(sig1_kim**2 + sig_astro**2)
# sig2 = sqrt(sig2_kim**2 + (2*sig_astro)**2) # 2sig is literally twice 1sig for the std-derived p.u.
# ```
#
# All of these steps are handled by `Align.CalcPU()`:

# %%
cd('../chapters')
from XRBID.Align import  CalcPU
cd('../testdata')

# Takes in DataFrame or Off-axis Angle/Counts and returns 1 and 2sig
# NOTE: theta needs to be in arcminutes, which is the default CSC unit
sig1, sig2 = CalcPU(M101_CSC, std=[0.3813,0.3037])
# Out:
# Invalid observation for source 10 . Setting radius to 0.
# Invalid observation for source 11 . Setting radius to 0.
# Invalid observation for source 13 . Setting radius to 0.
# Invalid observation for source 30 . Setting radius to 0.
# Invalid observation for source 31 . Setting radius to 0.
# Invalid observation for source 32 . Setting radius to 0.
# Invalid observation for source 34 . Setting radius to 0.
# Invalid observation for source 35 . Setting radius to 0.
# Invalid observation for source 36 . Setting radius to 0.
# Invalid observation for source 37 . Setting radius to 0.
# Invalid observation for source 38 . Setting radius to 0.
# Invalid observation for source 40 . Setting radius to 0.
# Invalid observation for source 41 . Setting radius to 0.
# Invalid observation for source 42 . Setting radius to 0.
# Invalid observation for source 43 . Setting radius to 0.
# Invalid observation for source 44 . Setting radius to 0.
# Invalid observation for source 46 . Setting radius to 0.
# Invalid observation for source 47 . Setting radius to 0.
# Invalid observation for source 48 . Setting radius to 0.
# Invalid observation for source 50 . Setting radius to 0.
# Invalid observation for source 51 . Setting radius to 0.
# Invalid observation for source 52 . Setting radius to 0.
# Invalid observation for source 53 . Setting radius to 0.
# Invalid observation for source 54 . Setting radius to 0.
# Invalid observation for source 55 . Setting radius to 0.
# Invalid observation for source 57 . Setting radius to 0.
# Invalid observation for source 58 . Setting radius to 0.
# Invalid observation for source 59 . Setting radius to 0.
# Invalid observation for source 60 . Setting radius to 0.
# Invalid observation for source 61 . Setting radius to 0.
# Invalid observation for source 62 . Setting radius to 0.
# Invalid observation for source 64 . Setting radius to 0.
# Invalid observation for source 65 . Setting radius to 0.
# Invalid observation for source 66 . Setting radius to 0.
# Invalid observation for source 67 . Setting radius to 0.
# Invalid observation for source 68 . Setting radius to 0.
# Invalid observation for source 77 . Setting radius to 0.
# Invalid observation for source 78 . Setting radius to 0.
# Invalid observation for source 79 . Setting radius to 0.
# Invalid observation for source 82 . Setting radius to 0.
# Invalid observation for source 86 . Setting radius to 0.
# Invalid observation for source 87 . Setting radius to 0.
# Invalid observation for source 88 . Setting radius to 0.
# Invalid observation for source 90 . Setting radius to 0.
# Invalid observation for source 96 . Setting radius to 0.
# Invalid observation for source 97 . Setting radius to 0.
# Invalid observation for source 106 . Setting radius to 0.
# Invalid observation for source 113 . Setting radius to 0.
# Invalid observation for source 114 . Setting radius to 0.
# Invalid observation for source 115 . Setting radius to 0.
# Invalid observation for source 116 . Setting radius to 0.
# Invalid observation for source 117 . Setting radius to 0.
# Invalid observation for source 118 . Setting radius to 0.
# Invalid observation for source 120 . Setting radius to 0.
# Invalid observation for source 121 . Setting radius to 0.
# Invalid observation for source 122 . Setting radius to 0.
# Invalid observation for source 123 . Setting radius to 0.
# Invalid observation for source 124 . Setting radius to 0.
# Invalid observation for source 125 . Setting radius to 0.
# Invalid observation for source 126 . Setting radius to 0.
# Invalid observation for source 134 . Setting radius to 0.
# Invalid observation for source 135 . Setting radius to 0.
# Invalid observation for source 143 . Setting radius to 0.
# Invalid observation for source 144 . Setting radius to 0.
# Invalid observation for source 145 . Setting radius to 0.
# Invalid observation for source 152 . Setting radius to 0.
# Invalid observation for source 154 . Setting radius to 0.
# Invalid observation for source 163 . Setting radius to 0.
# Invalid observation for source 164 . Setting radius to 0.
# Invalid observation for source 168 . Setting radius to 0.
# Invalid observation for source 169 . Setting radius to 0.
# Invalid observation for source 170 . Setting radius to 0.
# Invalid observation for source 171 . Setting radius to 0.
# Invalid observation for source 172 . Setting radius to 0.
# Invalid observation for source 173 . Setting radius to 0.
# Invalid observation for source 183 . Setting radius to 0.
# Invalid observation for source 184 . Setting radius to 0.
# Invalid observation for source 185 . Setting radius to 0.
# Invalid observation for source 187 . Setting radius to 0.
# Invalid observation for source 188 . Setting radius to 0.
# Invalid observation for source 189 . Setting radius to 0.
# Invalid observation for source 190 . Setting radius to 0.
# Invalid observation for source 191 . Setting radius to 0.
# Invalid observation for source 192 . Setting radius to 0.
# Invalid observation for source 193 . Setting radius to 0.
# Invalid observation for source 201 . Setting radius to 0.
# Invalid observation for source 202 . Setting radius to 0.
# Invalid observation for source 204 . Setting radius to 0.
# Invalid observation for source 205 . Setting radius to 0.
# Invalid observation for source 206 . Setting radius to 0.
# Invalid observation for source 207 . Setting radius to 0.
# Invalid observation for source 208 . Setting radius to 0.
# Invalid observation for source 209 . Setting radius to 0.
# Invalid observation for source 211 . Setting radius to 0.
# Invalid observation for source 212 . Setting radius to 0.
# Invalid observation for source 221 . Setting radius to 0.
# Invalid observation for source 222 . Setting radius to 0.
# Invalid observation for source 223 . Setting radius to 0.
# Invalid observation for source 224 . Setting radius to 0.
# Invalid observation for source 231 . Setting radius to 0.
# Invalid observation for source 232 . Setting radius to 0.
# Invalid observation for source 233 . Setting radius to 0.
# Invalid observation for source 241 . Setting radius to 0.
# Invalid observation for source 242 . Setting radius to 0.
# Invalid observation for source 243 . Setting radius to 0.
# Invalid observation for source 244 . Setting radius to 0.
# Invalid observation for source 245 . Setting radius to 0.
# Invalid observation for source 246 . Setting radius to 0.
# Invalid observation for source 247 . Setting radius to 0.
# Invalid observation for source 248 . Setting radius to 0.
# Invalid observation for source 250 . Setting radius to 0.
# Invalid observation for source 251 . Setting radius to 0.
# Invalid observation for source 252 . Setting radius to 0.
# Invalid observation for source 257 . Setting radius to 0.
# Invalid observation for source 259 . Setting radius to 0.
# Invalid observation for source 260 . Setting radius to 0.
# Invalid observation for source 261 . Setting radius to 0.
# Invalid observation for source 264 . Setting radius to 0.
# Invalid observation for source 266 . Setting radius to 0.
# Invalid observation for source 268 . Setting radius to 0.
# Invalid observation for source 269 . Setting radius to 0.
# Invalid observation for source 270 . Setting radius to 0.
# Invalid observation for source 271 . Setting radius to 0.
# Invalid observation for source 272 . Setting radius to 0.
# Invalid observation for source 273 . Setting radius to 0.
# Invalid observation for source 274 . Setting radius to 0.
# Invalid observation for source 276 . Setting radius to 0.
# Invalid observation for source 277 . Setting radius to 0.
# Invalid observation for source 278 . Setting radius to 0.
# Invalid observation for source 279 . Setting radius to 0.
# Invalid observation for source 280 . Setting radius to 0.
# Invalid observation for source 281 . Setting radius to 0.
# Invalid observation for source 283 . Setting radius to 0.
# Invalid observation for source 284 . Setting radius to 0.
# Invalid observation for source 286 . Setting radius to 0.
# Invalid observation for source 287 . Setting radius to 0.
# Invalid observation for source 288 . Setting radius to 0.
# Invalid observation for source 289 . Setting radius to 0.
# Invalid observation for source 290 . Setting radius to 0.
# Invalid observation for source 291 . Setting radius to 0.
# Invalid observation for source 292 . Setting radius to 0.
# Invalid observation for source 293 . Setting radius to 0.
# Invalid observation for source 294 . Setting radius to 0.
# Invalid observation for source 295 . Setting radius to 0.
# Invalid observation for source 296 . Setting radius to 0.
# Invalid observation for source 297 . Setting radius to 0.
# Invalid observation for source 298 . Setting radius to 0.
# Invalid observation for source 300 . Setting radius to 0.
# Invalid observation for source 301 . Setting radius to 0.
# Invalid observation for source 302 . Setting radius to 0.
# Invalid observation for source 303 . Setting radius to 0.
# Invalid observation for source 304 . Setting radius to 0.
# Invalid observation for source 305 . Setting radius to 0.
# Invalid observation for source 306 . Setting radius to 0.
# Invalid observation for source 308 . Setting radius to 0.
# Invalid observation for source 309 . Setting radius to 0.
# Invalid observation for source 310 . Setting radius to 0.
# Invalid observation for source 320 . Setting radius to 0.
# Invalid observation for source 326 . Setting radius to 0.
# Invalid observation for source 330 . Setting radius to 0.
# Invalid observation for source 331 . Setting radius to 0.
# Invalid observation for source 334 . Setting radius to 0.
# Invalid observation for source 335 . Setting radius to 0.
# Invalid observation for source 336 . Setting radius to 0.
# Invalid observation for source 337 . Setting radius to 0.
# Invalid observation for source 338 . Setting radius to 0.
# Invalid observation for source 339 . Setting radius to 0.
# Invalid observation for source 340 . Setting radius to 0.
# Invalid observation for source 349 . Setting radius to 0.
# Invalid observation for source 357 . Setting radius to 0.
# Invalid observation for source 358 . Setting radius to 0.
# Invalid observation for source 367 . Setting radius to 0.
# Invalid observation for source 368 . Setting radius to 0.
# Invalid observation for source 378 . Setting radius to 0.
# Invalid observation for source 380 . Setting radius to 0.
# Invalid observation for source 381 . Setting radius to 0.
# Invalid observation for source 382 . Setting radius to 0.
# Invalid observation for source 383 . Setting radius to 0.
# Invalid observation for source 384 . Setting radius to 0.
# Invalid observation for source 386 . Setting radius to 0.
# Invalid observation for source 387 . Setting radius to 0.
# Invalid observation for source 394 . Setting radius to 0.
# Invalid observation for source 396 . Setting radius to 0.
# Invalid observation for source 397 . Setting radius to 0.
# Invalid observation for source 399 . Setting radius to 0.
# Invalid observation for source 400 . Setting radius to 0.
# Invalid observation for source 401 . Setting radius to 0.
# Invalid observation for source 402 . Setting radius to 0.
# Invalid observation for source 403 . Setting radius to 0.
# Invalid observation for source 404 . Setting radius to 0.
# Invalid observation for source 405 . Setting radius to 0.
# Invalid observation for source 406 . Setting radius to 0.
# Invalid observation for source 407 . Setting radius to 0.
# Invalid observation for source 408 . Setting radius to 0.
# Invalid observation for source 409 . Setting radius to 0.
# Invalid observation for source 411 . Setting radius to 0.
# Invalid observation for source 412 . Setting radius to 0.
# Invalid observation for source 413 . Setting radius to 0.
# Invalid observation for source 414 . Setting radius to 0.
# Invalid observation for source 415 . Setting radius to 0.
# Invalid observation for source 416 . Setting radius to 0.
# Invalid observation for source 418 . Setting radius to 0.
# Invalid observation for source 419 . Setting radius to 0.
# Invalid observation for source 420 . Setting radius to 0.
# Invalid observation for source 421 . Setting radius to 0.
# Invalid observation for source 423 . Setting radius to 0.
# Invalid observation for source 424 . Setting radius to 0.
# Invalid observation for source 443 . Setting radius to 0.
# Invalid observation for source 444 . Setting radius to 0.
# Invalid observation for source 446 . Setting radius to 0.
# Invalid observation for source 447 . Setting radius to 0.
# Invalid observation for source 448 . Setting radius to 0.
# Invalid observation for source 449 . Setting radius to 0.
# Invalid observation for source 450 . Setting radius to 0.
# Invalid observation for source 451 . Setting radius to 0.
# Invalid observation for source 452 . Setting radius to 0.
# Invalid observation for source 453 . Setting radius to 0.
# Invalid observation for source 461 . Setting radius to 0.
# Invalid observation for source 462 . Setting radius to 0.
# Invalid observation for source 472 . Setting radius to 0.
# Invalid observation for source 477 . Setting radius to 0.
# Invalid observation for source 479 . Setting radius to 0.
# Invalid observation for source 480 . Setting radius to 0.
# Invalid observation for source 481 . Setting radius to 0.
# Invalid observation for source 490 . Setting radius to 0.
# Invalid observation for source 491 . Setting radius to 0.
# Invalid observation for source 492 . Setting radius to 0.
# Invalid observation for source 493 . Setting radius to 0.
# Invalid observation for source 495 . Setting radius to 0.
# Invalid observation for source 497 . Setting radius to 0.
# Invalid observation for source 498 . Setting radius to 0.
# Invalid observation for source 499 . Setting radius to 0.
# Invalid observation for source 500 . Setting radius to 0.
# Invalid observation for source 501 . Setting radius to 0.
# Invalid observation for source 502 . Setting radius to 0.
# Invalid observation for source 503 . Setting radius to 0.
# Invalid observation for source 504 . Setting radius to 0.
# Invalid observation for source 505 . Setting radius to 0.
# Invalid observation for source 506 . Setting radius to 0.
# Invalid observation for source 508 . Setting radius to 0.
# Invalid observation for source 509 . Setting radius to 0.
# Invalid observation for source 510 . Setting radius to 0.
# Invalid observation for source 511 . Setting radius to 0.
# Invalid observation for source 512 . Setting radius to 0.
# Invalid observation for source 513 . Setting radius to 0.
# Invalid observation for source 514 . Setting radius to 0.
# Invalid observation for source 515 . Setting radius to 0.
# Invalid observation for source 516 . Setting radius to 0.
# Invalid observation for source 517 . Setting radius to 0.
# Invalid observation for source 519 . Setting radius to 0.
# Invalid observation for source 526 . Setting radius to 0.
# Invalid observation for source 527 . Setting radius to 0.
# Invalid observation for source 528 . Setting radius to 0.
# Invalid observation for source 530 . Setting radius to 0.
# Invalid observation for source 531 . Setting radius to 0.
# Invalid observation for source 532 . Setting radius to 0.
# Invalid observation for source 533 . Setting radius to 0.
# Invalid observation for source 534 . Setting radius to 0.
# Invalid observation for source 535 . Setting radius to 0.
# Invalid observation for source 536 . Setting radius to 0.
# Invalid observation for source 537 . Setting radius to 0.
# Invalid observation for source 546 . Setting radius to 0.
# Invalid observation for source 551 . Setting radius to 0.
# Invalid observation for source 554 . Setting radius to 0.
# Invalid observation for source 555 . Setting radius to 0.
# Invalid observation for source 557 . Setting radius to 0.
# Invalid observation for source 561 . Setting radius to 0.
# Invalid observation for source 564 . Setting radius to 0.
# Invalid observation for source 565 . Setting radius to 0.
# Invalid observation for source 566 . Setting radius to 0.
# Invalid observation for source 567 . Setting radius to 0.
# Invalid observation for source 568 . Setting radius to 0.
# Invalid observation for source 569 . Setting radius to 0.
# Invalid observation for source 570 . Setting radius to 0.
# Invalid observation for source 572 . Setting radius to 0.
# Invalid observation for source 573 . Setting radius to 0.
# Invalid observation for source 592 . Setting radius to 0.
# Invalid observation for source 611 . Setting radius to 0.
# Invalid observation for source 612 . Setting radius to 0.
# Invalid observation for source 620 . Setting radius to 0.
# Invalid observation for source 622 . Setting radius to 0.
# Invalid observation for source 623 . Setting radius to 0.
# Invalid observation for source 625 . Setting radius to 0.
# Invalid observation for source 627 . Setting radius to 0.
# Invalid observation for source 629 . Setting radius to 0.
# Invalid observation for source 632 . Setting radius to 0.
# Invalid observation for source 635 . Setting radius to 0.
# Invalid observation for source 638 . Setting radius to 0.
# Invalid observation for source 639 . Setting radius to 0.
# Invalid observation for source 641 . Setting radius to 0.
# Invalid observation for source 643 . Setting radius to 0.
# Invalid observation for source 646 . Setting radius to 0.
# Invalid observation for source 650 . Setting radius to 0.
# Invalid observation for source 655 . Setting radius to 0.
# Invalid observation for source 659 . Setting radius to 0.
# Invalid observation for source 660 . Setting radius to 0.
# Invalid observation for source 661 . Setting radius to 0.
# Invalid observation for source 668 . Setting radius to 0.
# Invalid observation for source 683 . Setting radius to 0.
# Invalid observation for source 686 . Setting radius to 0.
# Invalid observation for source 688 . Setting radius to 0.
# Invalid observation for source 690 . Setting radius to 0.
# Invalid observation for source 691 . Setting radius to 0.
# Invalid observation for source 693 . Setting radius to 0.
# Invalid observation for source 694 . Setting radius to 0.
# Invalid observation for source 695 . Setting radius to 0.
# Invalid observation for source 696 . Setting radius to 0.
# Invalid observation for source 697 . Setting radius to 0.
# Invalid observation for source 709 . Setting radius to 0.
# Invalid observation for source 710 . Setting radius to 0.
# Invalid observation for source 711 . Setting radius to 0.
# Invalid observation for source 712 . Setting radius to 0.
# Invalid observation for source 713 . Setting radius to 0.
# Invalid observation for source 714 . Setting radius to 0.
# Invalid observation for source 715 . Setting radius to 0.
# Invalid observation for source 716 . Setting radius to 0.
# Invalid observation for source 723 . Setting radius to 0.
# Invalid observation for source 724 . Setting radius to 0.
# Invalid observation for source 725 . Setting radius to 0.
# Invalid observation for source 733 . Setting radius to 0.
# Invalid observation for source 734 . Setting radius to 0.
# Invalid observation for source 735 . Setting radius to 0.
# Invalid observation for source 736 . Setting radius to 0.
# Invalid observation for source 737 . Setting radius to 0.
# Invalid observation for source 738 . Setting radius to 0.
# Invalid observation for source 739 . Setting radius to 0.
# Invalid observation for source 741 . Setting radius to 0.
# Invalid observation for source 742 . Setting radius to 0.
# Invalid observation for source 743 . Setting radius to 0.
# Invalid observation for source 747 . Setting radius to 0.
# Invalid observation for source 751 . Setting radius to 0.
# Invalid observation for source 752 . Setting radius to 0.
# Invalid observation for source 754 . Setting radius to 0.
# Invalid observation for source 755 . Setting radius to 0.
# Invalid observation for source 756 . Setting radius to 0.
# Invalid observation for source 757 . Setting radius to 0.
# Invalid observation for source 758 . Setting radius to 0.
# Invalid observation for source 759 . Setting radius to 0.
# Invalid observation for source 760 . Setting radius to 0.
# Invalid observation for source 761 . Setting radius to 0.
# Invalid observation for source 770 . Setting radius to 0.
# Invalid observation for source 772 . Setting radius to 0.
# Invalid observation for source 773 . Setting radius to 0.
# Invalid observation for source 774 . Setting radius to 0.
# Invalid observation for source 775 . Setting radius to 0.
# Invalid observation for source 776 . Setting radius to 0.
# Invalid observation for source 777 . Setting radius to 0.
# Invalid observation for source 778 . Setting radius to 0.
# Invalid observation for source 779 . Setting radius to 0.
# Invalid observation for source 781 . Setting radius to 0.
# Invalid observation for source 784 . Setting radius to 0.
# Invalid observation for source 788 . Setting radius to 0.
# Invalid observation for source 790 . Setting radius to 0.
# Invalid observation for source 791 . Setting radius to 0.
# Invalid observation for source 792 . Setting radius to 0.
# Invalid observation for source 793 . Setting radius to 0.
# Invalid observation for source 794 . Setting radius to 0.
# Invalid observation for source 795 . Setting radius to 0.
# Invalid observation for source 796 . Setting radius to 0.
# Invalid observation for source 797 . Setting radius to 0.
# Invalid observation for source 799 . Setting radius to 0.
# Invalid observation for source 800 . Setting radius to 0.
# Invalid observation for source 801 . Setting radius to 0.
# Invalid observation for source 802 . Setting radius to 0.
# Invalid observation for source 803 . Setting radius to 0.
# Invalid observation for source 804 . Setting radius to 0.
# Invalid observation for source 805 . Setting radius to 0.
# Invalid observation for source 806 . Setting radius to 0.
# Invalid observation for source 808 . Setting radius to 0.
# Invalid observation for source 815 . Setting radius to 0.
# Invalid observation for source 818 . Setting radius to 0.
# Invalid observation for source 820 . Setting radius to 0.
# Invalid observation for source 821 . Setting radius to 0.
# Invalid observation for source 822 . Setting radius to 0.
# Invalid observation for source 823 . Setting radius to 0.
# Invalid observation for source 824 . Setting radius to 0.
# Invalid observation for source 826 . Setting radius to 0.
# Invalid observation for source 827 . Setting radius to 0.
# Invalid observation for source 829 . Setting radius to 0.
# Invalid observation for source 831 . Setting radius to 0.
# Invalid observation for source 832 . Setting radius to 0.
# Invalid observation for source 833 . Setting radius to 0.
# Invalid observation for source 853 . Setting radius to 0.
# Invalid observation for source 854 . Setting radius to 0.
# Invalid observation for source 855 . Setting radius to 0.
# Invalid observation for source 856 . Setting radius to 0.
# Invalid observation for source 857 . Setting radius to 0.
# Invalid observation for source 859 . Setting radius to 0.
# Invalid observation for source 860 . Setting radius to 0.
# Invalid observation for source 861 . Setting radius to 0.
# Invalid observation for source 874 . Setting radius to 0.
# Invalid observation for source 875 . Setting radius to 0.
# Invalid observation for source 878 . Setting radius to 0.
# Invalid observation for source 879 . Setting radius to 0.
# Invalid observation for source 881 . Setting radius to 0.
# Invalid observation for source 882 . Setting radius to 0.
# Invalid observation for source 884 . Setting radius to 0.
# Invalid observation for source 887 . Setting radius to 0.
# Invalid observation for source 891 . Setting radius to 0.
# Invalid observation for source 897 . Setting radius to 0.
# Invalid observation for source 898 . Setting radius to 0.
# Invalid observation for source 899 . Setting radius to 0.
# Invalid observation for source 901 . Setting radius to 0.
# Invalid observation for source 903 . Setting radius to 0.
# Invalid observation for source 904 . Setting radius to 0.
# Invalid observation for source 905 . Setting radius to 0.
# Invalid observation for source 912 . Setting radius to 0.
# Invalid observation for source 915 . Setting radius to 0.
# Invalid observation for source 916 . Setting radius to 0.
# Invalid observation for source 920 . Setting radius to 0.
# Invalid observation for source 924 . Setting radius to 0.
# Invalid observation for source 927 . Setting radius to 0.
# Invalid observation for source 929 . Setting radius to 0.
# Invalid observation for source 930 . Setting radius to 0.
# Invalid observation for source 931 . Setting radius to 0.
# Invalid observation for source 932 . Setting radius to 0.
# Invalid observation for source 933 . Setting radius to 0.
# Invalid observation for source 934 . Setting radius to 0.
# Invalid observation for source 935 . Setting radius to 0.
# Invalid observation for source 938 . Setting radius to 0.
# Invalid observation for source 950 . Setting radius to 0.
# Invalid observation for source 952 . Setting radius to 0.
# Invalid observation for source 964 . Setting radius to 0.
# Invalid observation for source 965 . Setting radius to 0.
# Invalid observation for source 969 . Setting radius to 0.
# Invalid observation for source 974 . Setting radius to 0.
# Invalid observation for source 977 . Setting radius to 0.
# Invalid observation for source 982 . Setting radius to 0.
# Invalid observation for source 984 . Setting radius to 0.
# Invalid observation for source 987 . Setting radius to 0.
# Invalid observation for source 988 . Setting radius to 0.
# Invalid observation for source 990 . Setting radius to 0.
# Invalid observation for source 997 . Setting radius to 0.
# Invalid observation for source 998 . Setting radius to 0.
# Invalid observation for source 999 . Setting radius to 0.
# Invalid observation for source 1000 . Setting radius to 0.
# Invalid observation for source 1002 . Setting radius to 0.
# Invalid observation for source 1005 . Setting radius to 0.
# Invalid observation for source 1006 . Setting radius to 0.
# Invalid observation for source 1007 . Setting radius to 0.
# Invalid observation for source 1008 . Setting radius to 0.
# Invalid observation for source 1011 . Setting radius to 0.
# Invalid observation for source 1012 . Setting radius to 0.
# Invalid observation for source 1013 . Setting radius to 0.
# Invalid observation for source 1014 . Setting radius to 0.
# Invalid observation for source 1015 . Setting radius to 0.
# Invalid observation for source 1037 . Setting radius to 0.
# Invalid observation for source 1039 . Setting radius to 0.
# Invalid observation for source 1041 . Setting radius to 0.
# Invalid observation for source 1042 . Setting radius to 0.
# Invalid observation for source 1046 . Setting radius to 0.
# Invalid observation for source 1047 . Setting radius to 0.
# Invalid observation for source 1048 . Setting radius to 0.
# Invalid observation for source 1049 . Setting radius to 0.
# Invalid observation for source 1050 . Setting radius to 0.
# Invalid observation for source 1051 . Setting radius to 0.
# Invalid observation for source 1052 . Setting radius to 0.
# Invalid observation for source 1053 . Setting radius to 0.
# Invalid observation for source 1054 . Setting radius to 0.
# Invalid observation for source 1055 . Setting radius to 0.
# Invalid observation for source 1056 . Setting radius to 0.
# Invalid observation for source 1057 . Setting radius to 0.
# Invalid observation for source 1058 . Setting radius to 0.
# Invalid observation for source 1059 . Setting radius to 0.
# Invalid observation for source 1061 . Setting radius to 0.
# Invalid observation for source 1073 . Setting radius to 0.
# Invalid observation for source 1074 . Setting radius to 0.
# Invalid observation for source 1077 . Setting radius to 0.
# Invalid observation for source 1080 . Setting radius to 0.
# Invalid observation for source 1081 . Setting radius to 0.
# Invalid observation for source 1088 . Setting radius to 0.
# Invalid observation for source 1089 . Setting radius to 0.
# Invalid observation for source 1091 . Setting radius to 0.
# Invalid observation for source 1094 . Setting radius to 0.
# Invalid observation for source 1095 . Setting radius to 0.
# Invalid observation for source 1096 . Setting radius to 0.
# Invalid observation for source 1097 . Setting radius to 0.
# Invalid observation for source 1098 . Setting radius to 0.
# Invalid observation for source 1099 . Setting radius to 0.
# Invalid observation for source 1100 . Setting radius to 0.
# Invalid observation for source 1103 . Setting radius to 0.
# Invalid observation for source 1104 . Setting radius to 0.
# Invalid observation for source 1105 . Setting radius to 0.
# Invalid observation for source 1106 . Setting radius to 0.
# Invalid observation for source 1107 . Setting radius to 0.
# Invalid observation for source 1108 . Setting radius to 0.
# Invalid observation for source 1109 . Setting radius to 0.
# Invalid observation for source 1126 . Setting radius to 0.
# Invalid observation for source 1128 . Setting radius to 0.
# Invalid observation for source 1129 . Setting radius to 0.
# Invalid observation for source 1130 . Setting radius to 0.
# Invalid observation for source 1131 . Setting radius to 0.
# Invalid observation for source 1132 . Setting radius to 0.
# Invalid observation for source 1133 . Setting radius to 0.
# Invalid observation for source 1134 . Setting radius to 0.
# Invalid observation for source 1135 . Setting radius to 0.
# Invalid observation for source 1136 . Setting radius to 0.
# Invalid observation for source 1137 . Setting radius to 0.
# Invalid observation for source 1138 . Setting radius to 0.
# Invalid observation for source 1139 . Setting radius to 0.
# Invalid observation for source 1141 . Setting radius to 0.
# Invalid observation for source 1142 . Setting radius to 0.
# Invalid observation for source 1143 . Setting radius to 0.
# Invalid observation for source 1144 . Setting radius to 0.
# Invalid observation for source 1145 . Setting radius to 0.
# Invalid observation for source 1146 . Setting radius to 0.
# Invalid observation for source 1148 . Setting radius to 0.
# Invalid observation for source 1149 . Setting radius to 0.
# Invalid observation for source 1151 . Setting radius to 0.
# Invalid observation for source 1152 . Setting radius to 0.
# Invalid observation for source 1153 . Setting radius to 0.
# Invalid observation for source 1163 . Setting radius to 0.
# Invalid observation for source 1166 . Setting radius to 0.
# Invalid observation for source 1168 . Setting radius to 0.
# Invalid observation for source 1170 . Setting radius to 0.
# Invalid observation for source 1171 . Setting radius to 0.
# Invalid observation for source 1172 . Setting radius to 0.
# Invalid observation for source 1180 . Setting radius to 0.
# Invalid observation for source 1181 . Setting radius to 0.
# Invalid observation for source 1193 . Setting radius to 0.
# Invalid observation for source 1194 . Setting radius to 0.
# Invalid observation for source 1198 . Setting radius to 0.
# Invalid observation for source 1200 . Setting radius to 0.
# Invalid observation for source 1201 . Setting radius to 0.
# Invalid observation for source 1203 . Setting radius to 0.
# Invalid observation for source 1204 . Setting radius to 0.
# Invalid observation for source 1205 . Setting radius to 0.
# Invalid observation for source 1206 . Setting radius to 0.
# Invalid observation for source 1208 . Setting radius to 0.
# Invalid observation for source 1209 . Setting radius to 0.
# Invalid observation for source 1210 . Setting radius to 0.
# Invalid observation for source 1211 . Setting radius to 0.
# Invalid observation for source 1212 . Setting radius to 0.
# Invalid observation for source 1214 . Setting radius to 0.
# Invalid observation for source 1215 . Setting radius to 0.
# Invalid observation for source 1216 . Setting radius to 0.
# Invalid observation for source 1217 . Setting radius to 0.
# Invalid observation for source 1224 . Setting radius to 0.
# Invalid observation for source 1225 . Setting radius to 0.
# Invalid observation for source 1226 . Setting radius to 0.
# Invalid observation for source 1227 . Setting radius to 0.
# Invalid observation for source 1228 . Setting radius to 0.
# Invalid observation for source 1231 . Setting radius to 0.
# Invalid observation for source 1233 . Setting radius to 0.
# Invalid observation for source 1235 . Setting radius to 0.
# Invalid observation for source 1237 . Setting radius to 0.
# Invalid observation for source 1238 . Setting radius to 0.
# Invalid observation for source 1239 . Setting radius to 0.
# Invalid observation for source 1240 . Setting radius to 0.
# Invalid observation for source 1241 . Setting radius to 0.
# Invalid observation for source 1242 . Setting radius to 0.
# Invalid observation for source 1243 . Setting radius to 0.
# Invalid observation for source 1244 . Setting radius to 0.
# Invalid observation for source 1247 . Setting radius to 0.
# Invalid observation for source 1249 . Setting radius to 0.
# Invalid observation for source 1250 . Setting radius to 0.
# Invalid observation for source 1251 . Setting radius to 0.
# Invalid observation for source 1256 . Setting radius to 0.
# Invalid observation for source 1258 . Setting radius to 0.
# Invalid observation for source 1259 . Setting radius to 0.
# Invalid observation for source 1260 . Setting radius to 0.
# Invalid observation for source 1261 . Setting radius to 0.
# Invalid observation for source 1269 . Setting radius to 0.
# Invalid observation for source 1278 . Setting radius to 0.
# Invalid observation for source 1279 . Setting radius to 0.
# Invalid observation for source 1280 . Setting radius to 0.
# Invalid observation for source 1282 . Setting radius to 0.
# Invalid observation for source 1283 . Setting radius to 0.
# Invalid observation for source 1284 . Setting radius to 0.
# Invalid observation for source 1285 . Setting radius to 0.
# Invalid observation for source 1286 . Setting radius to 0.
# Invalid observation for source 1287 . Setting radius to 0.
# Invalid observation for source 1295 . Setting radius to 0.
# Invalid observation for source 1296 . Setting radius to 0.
# Invalid observation for source 1297 . Setting radius to 0.
# Invalid observation for source 1299 . Setting radius to 0.
# Invalid observation for source 1300 . Setting radius to 0.
# Invalid observation for source 1301 . Setting radius to 0.
# Invalid observation for source 1302 . Setting radius to 0.
# Invalid observation for source 1303 . Setting radius to 0.
# Invalid observation for source 1304 . Setting radius to 0.
# Invalid observation for source 1305 . Setting radius to 0.
# Invalid observation for source 1307 . Setting radius to 0.
# Invalid observation for source 1308 . Setting radius to 0.
# Invalid observation for source 1309 . Setting radius to 0.
# Invalid observation for source 1310 . Setting radius to 0.
# Invalid observation for source 1311 . Setting radius to 0.
# Invalid observation for source 1312 . Setting radius to 0.
# Invalid observation for source 1313 . Setting radius to 0.
# Invalid observation for source 1316 . Setting radius to 0.
# Invalid observation for source 1320 . Setting radius to 0.
# Invalid observation for source 1321 . Setting radius to 0.
# Invalid observation for source 1322 . Setting radius to 0.
# Invalid observation for source 1330 . Setting radius to 0.
# Invalid observation for source 1332 . Setting radius to 0.
# Invalid observation for source 1333 . Setting radius to 0.
# Invalid observation for source 1335 . Setting radius to 0.
# Invalid observation for source 1336 . Setting radius to 0.
# Invalid observation for source 1337 . Setting radius to 0.
# Invalid observation for source 1338 . Setting radius to 0.
# Invalid observation for source 1340 . Setting radius to 0.
# Invalid observation for source 1341 . Setting radius to 0.
# Invalid observation for source 1343 . Setting radius to 0.
# Invalid observation for source 1344 . Setting radius to 0.
# Invalid observation for source 1345 . Setting radius to 0.
# Invalid observation for source 1346 . Setting radius to 0.
# Invalid observation for source 1347 . Setting radius to 0.
# Invalid observation for source 1348 . Setting radius to 0.
# Invalid observation for source 1350 . Setting radius to 0.
# Invalid observation for source 1351 . Setting radius to 0.
# Invalid observation for source 1352 . Setting radius to 0.
# Invalid observation for source 1353 . Setting radius to 0.
# Invalid observation for source 1354 . Setting radius to 0.
# Invalid observation for source 1355 . Setting radius to 0.
# Invalid observation for source 1359 . Setting radius to 0.
# Invalid observation for source 1360 . Setting radius to 0.
# Invalid observation for source 1361 . Setting radius to 0.
# Invalid observation for source 1362 . Setting radius to 0.
# Invalid observation for source 1363 . Setting radius to 0.
# Invalid observation for source 1364 . Setting radius to 0.
# Invalid observation for source 1365 . Setting radius to 0.
# Invalid observation for source 1366 . Setting radius to 0.
# Invalid observation for source 1367 . Setting radius to 0.
# Invalid observation for source 1368 . Setting radius to 0.
# Invalid observation for source 1369 . Setting radius to 0.
# Invalid observation for source 1371 . Setting radius to 0.
# Invalid observation for source 1373 . Setting radius to 0.
# Invalid observation for source 1375 . Setting radius to 0.
# Invalid observation for source 1376 . Setting radius to 0.
# Invalid observation for source 1377 . Setting radius to 0.
# Invalid observation for source 1378 . Setting radius to 0.
# Invalid observation for source 1379 . Setting radius to 0.
# Invalid observation for source 1380 . Setting radius to 0.
# Invalid observation for source 1381 . Setting radius to 0.
# Invalid observation for source 1382 . Setting radius to 0.
# Invalid observation for source 1387 . Setting radius to 0.
# Invalid observation for source 1389 . Setting radius to 0.
# Invalid observation for source 1391 . Setting radius to 0.
# Invalid observation for source 1392 . Setting radius to 0.
# Invalid observation for source 1393 . Setting radius to 0.
# Invalid observation for source 1395 . Setting radius to 0.
# Invalid observation for source 1396 . Setting radius to 0.
# Invalid observation for source 1398 . Setting radius to 0.
# Invalid observation for source 1399 . Setting radius to 0.
# Invalid observation for source 1400 . Setting radius to 0.
# Invalid observation for source 1403 . Setting radius to 0.
# Invalid observation for source 1405 . Setting radius to 0.
# Invalid observation for source 1406 . Setting radius to 0.
# Invalid observation for source 1407 . Setting radius to 0.
# Invalid observation for source 1409 . Setting radius to 0.
# Invalid observation for source 1410 . Setting radius to 0.
# Invalid observation for source 1411 . Setting radius to 0.
# Invalid observation for source 1412 . Setting radius to 0.
# Invalid observation for source 1413 . Setting radius to 0.
# Invalid observation for source 1414 . Setting radius to 0.
# Invalid observation for source 1415 . Setting radius to 0.
# Invalid observation for source 1416 . Setting radius to 0.
# Invalid observation for source 1427 . Setting radius to 0.
# Invalid observation for source 1428 . Setting radius to 0.
# Invalid observation for source 1429 . Setting radius to 0.
# Invalid observation for source 1431 . Setting radius to 0.
# Invalid observation for source 1432 . Setting radius to 0.
# Invalid observation for source 1434 . Setting radius to 0.
# Invalid observation for source 1436 . Setting radius to 0.
# Invalid observation for source 1437 . Setting radius to 0.
# Invalid observation for source 1441 . Setting radius to 0.
# Invalid observation for source 1442 . Setting radius to 0.
# Invalid observation for source 1444 . Setting radius to 0.
# Invalid observation for source 1446 . Setting radius to 0.
# Invalid observation for source 1447 . Setting radius to 0.
# Invalid observation for source 1449 . Setting radius to 0.
# Invalid observation for source 1450 . Setting radius to 0.
# Invalid observation for source 1452 . Setting radius to 0.
# Invalid observation for source 1453 . Setting radius to 0.
# Invalid observation for source 1454 . Setting radius to 0.
# Invalid observation for source 1455 . Setting radius to 0.
# Invalid observation for source 1456 . Setting radius to 0.
# Invalid observation for source 1457 . Setting radius to 0.
# Invalid observation for source 1458 . Setting radius to 0.
# Invalid observation for source 1459 . Setting radius to 0.
# Invalid observation for source 1460 . Setting radius to 0.
# Invalid observation for source 1471 . Setting radius to 0.
# Invalid observation for source 1475 . Setting radius to 0.
# Invalid observation for source 1476 . Setting radius to 0.
# Invalid observation for source 1478 . Setting radius to 0.
# Invalid observation for source 1479 . Setting radius to 0.
# Invalid observation for source 1485 . Setting radius to 0.
# Invalid observation for source 1487 . Setting radius to 0.
# Invalid observation for source 1488 . Setting radius to 0.
# Invalid observation for source 1490 . Setting radius to 0.
# Invalid observation for source 1491 . Setting radius to 0.
# Invalid observation for source 1492 . Setting radius to 0.
# Invalid observation for source 1493 . Setting radius to 0.
# Invalid observation for source 1495 . Setting radius to 0.
# Invalid observation for source 1496 . Setting radius to 0.
# Invalid observation for source 1497 . Setting radius to 0.
# Invalid observation for source 1502 . Setting radius to 0.
# Invalid observation for source 1506 . Setting radius to 0.
# Invalid observation for source 1507 . Setting radius to 0.
# Invalid observation for source 1510 . Setting radius to 0.
# Invalid observation for source 1511 . Setting radius to 0.
# Invalid observation for source 1513 . Setting radius to 0.
# Invalid observation for source 1514 . Setting radius to 0.
# Invalid observation for source 1523 . Setting radius to 0.
# Invalid observation for source 1525 . Setting radius to 0.
# Invalid observation for source 1526 . Setting radius to 0.
# Invalid observation for source 1527 . Setting radius to 0.
# Invalid observation for source 1528 . Setting radius to 0.
# Invalid observation for source 1529 . Setting radius to 0.
# Invalid observation for source 1530 . Setting radius to 0.
# Invalid observation for source 1531 . Setting radius to 0.
# Invalid observation for source 1542 . Setting radius to 0.
# Invalid observation for source 1547 . Setting radius to 0.
# Invalid observation for source 1548 . Setting radius to 0.
# Invalid observation for source 1556 . Setting radius to 0.
# Invalid observation for source 1558 . Setting radius to 0.
# Invalid observation for source 1559 . Setting radius to 0.
# Invalid observation for source 1560 . Setting radius to 0.
# Invalid observation for source 1563 . Setting radius to 0.
# Invalid observation for source 1564 . Setting radius to 0.
# Invalid observation for source 1565 . Setting radius to 0.
# Invalid observation for source 1567 . Setting radius to 0.
# Invalid observation for source 1568 . Setting radius to 0.
# Invalid observation for source 1569 . Setting radius to 0.
# Invalid observation for source 1570 . Setting radius to 0.
# Invalid observation for source 1571 . Setting radius to 0.
# Invalid observation for source 1572 . Setting radius to 0.
# Invalid observation for source 1573 . Setting radius to 0.
# Invalid observation for source 1574 . Setting radius to 0.
# Invalid observation for source 1575 . Setting radius to 0.
# Invalid observation for source 1576 . Setting radius to 0.
# Invalid observation for source 1578 . Setting radius to 0.
# Invalid observation for source 1579 . Setting radius to 0.
# Invalid observation for source 1580 . Setting radius to 0.
# Invalid observation for source 1581 . Setting radius to 0.
# Invalid observation for source 1582 . Setting radius to 0.
# Invalid observation for source 1583 . Setting radius to 0.
# Invalid observation for source 1584 . Setting radius to 0.
# Invalid observation for source 1585 . Setting radius to 0.
# Invalid observation for source 1586 . Setting radius to 0.
# Invalid observation for source 1587 . Setting radius to 0.
# Invalid observation for source 1588 . Setting radius to 0.
# Invalid observation for source 1589 . Setting radius to 0.
# Invalid observation for source 1591 . Setting radius to 0.
# Invalid observation for source 1593 . Setting radius to 0.
# Invalid observation for source 1594 . Setting radius to 0.
# Invalid observation for source 1595 . Setting radius to 0.
# Invalid observation for source 1596 . Setting radius to 0.
# Invalid observation for source 1597 . Setting radius to 0.
# Invalid observation for source 1598 . Setting radius to 0.
# Invalid observation for source 1599 . Setting radius to 0.
# Invalid observation for source 1605 . Setting radius to 0.
# Invalid observation for source 1611 . Setting radius to 0.
# Invalid observation for source 1612 . Setting radius to 0.
# Invalid observation for source 1616 . Setting radius to 0.
# Invalid observation for source 1617 . Setting radius to 0.
# Invalid observation for source 1618 . Setting radius to 0.
# Invalid observation for source 1619 . Setting radius to 0.
# Invalid observation for source 1621 . Setting radius to 0.
# Invalid observation for source 1622 . Setting radius to 0.
# Invalid observation for source 1623 . Setting radius to 0.
# Invalid observation for source 1624 . Setting radius to 0.
# Invalid observation for source 1632 . Setting radius to 0.
# Invalid observation for source 1633 . Setting radius to 0.
# Invalid observation for source 1634 . Setting radius to 0.
# Invalid observation for source 1636 . Setting radius to 0.
# Invalid observation for source 1637 . Setting radius to 0.
# Invalid observation for source 1638 . Setting radius to 0.
# Invalid observation for source 1639 . Setting radius to 0.
# Invalid observation for source 1640 . Setting radius to 0.
# Invalid observation for source 1642 . Setting radius to 0.
# Invalid observation for source 1644 . Setting radius to 0.
# Invalid observation for source 1645 . Setting radius to 0.
# Invalid observation for source 1646 . Setting radius to 0.
# Invalid observation for source 1647 . Setting radius to 0.
# Invalid observation for source 1649 . Setting radius to 0.
# Invalid observation for source 1650 . Setting radius to 0.
# Invalid observation for source 1651 . Setting radius to 0.
# Invalid observation for source 1652 . Setting radius to 0.
# Invalid observation for source 1653 . Setting radius to 0.
# Invalid observation for source 1654 . Setting radius to 0.
# Invalid observation for source 1655 . Setting radius to 0.
# Invalid observation for source 1656 . Setting radius to 0.
# Invalid observation for source 1658 . Setting radius to 0.
# Invalid observation for source 1659 . Setting radius to 0.
# Invalid observation for source 1661 . Setting radius to 0.
# Invalid observation for source 1662 . Setting radius to 0.
# Invalid observation for source 1663 . Setting radius to 0.
# Invalid observation for source 1671 . Setting radius to 0.
# Invalid observation for source 1672 . Setting radius to 0.
# Invalid observation for source 1674 . Setting radius to 0.
# Invalid observation for source 1675 . Setting radius to 0.
# Invalid observation for source 1676 . Setting radius to 0.
# Invalid observation for source 1679 . Setting radius to 0.
# Invalid observation for source 1680 . Setting radius to 0.
# Invalid observation for source 1681 . Setting radius to 0.
# Invalid observation for source 1682 . Setting radius to 0.
# Invalid observation for source 1686 . Setting radius to 0.
# Invalid observation for source 1688 . Setting radius to 0.
# Invalid observation for source 1691 . Setting radius to 0.
# Invalid observation for source 1693 . Setting radius to 0.
# Invalid observation for source 1696 . Setting radius to 0.
# Invalid observation for source 1698 . Setting radius to 0.
# Invalid observation for source 1700 . Setting radius to 0.
# Invalid observation for source 1701 . Setting radius to 0.
# Invalid observation for source 1702 . Setting radius to 0.
# Invalid observation for source 1704 . Setting radius to 0.
# Invalid observation for source 1705 . Setting radius to 0.
# Invalid observation for source 1706 . Setting radius to 0.
# Invalid observation for source 1707 . Setting radius to 0.
# Invalid observation for source 1708 . Setting radius to 0.
# Invalid observation for source 1709 . Setting radius to 0.
# Invalid observation for source 1719 . Setting radius to 0.
# Invalid observation for source 1720 . Setting radius to 0.
# Invalid observation for source 1721 . Setting radius to 0.
# Invalid observation for source 1722 . Setting radius to 0.
# Invalid observation for source 1723 . Setting radius to 0.
# Invalid observation for source 1729 . Setting radius to 0.
# Invalid observation for source 1732 . Setting radius to 0.
# Invalid observation for source 1733 . Setting radius to 0.
# Invalid observation for source 1734 . Setting radius to 0.
# ...
# Invalid observation for source 2784 . Setting radius to 0.
# Invalid observation for source 2785 . Setting radius to 0.
# Invalid observation for source 2786 . Setting radius to 0.
# Invalid observation for source 2787 . Setting radius to 0.
# Invalid observation for source 2795 . Setting radius to 0.
# Invalid observation for source 2799 . Setting radius to 0.
# Invalid observation for source 2800 . Setting radius to 0.
# Invalid observation for source 2802 . Setting radius to 0.
# Invalid observation for source 2804 . Setting radius to 0.
# Invalid observation for source 2805 . Setting radius to 0.
# Invalid observation for source 2806 . Setting radius to 0.
# Invalid observation for source 2807 . Setting radius to 0.
# Invalid observation for source 2808 . Setting radius to 0.
# Invalid observation for source 2810 . Setting radius to 0.
# Invalid observation for source 2812 . Setting radius to 0.
# Invalid observation for source 2813 . Setting radius to 0.
# Invalid observation for source 2815 . Setting radius to 0.
# Invalid observation for source 2820 . Setting radius to 0.
# Invalid observation for source 2822 . Setting radius to 0.
# Invalid observation for source 2823 . Setting radius to 0.
# Invalid observation for source 2825 . Setting radius to 0.
# Invalid observation for source 2826 . Setting radius to 0.
# Invalid observation for source 2828 . Setting radius to 0.
# Invalid observation for source 2850 . Setting radius to 0.
# Invalid observation for source 2851 . Setting radius to 0.
# Invalid observation for source 2853 . Setting radius to 0.
# Invalid observation for source 2857 . Setting radius to 0.
# Invalid observation for source 2858 . Setting radius to 0.
# Invalid observation for source 2861 . Setting radius to 0.
# Invalid observation for source 2862 . Setting radius to 0.
# Invalid observation for source 2863 . Setting radius to 0.
# Invalid observation for source 2870 . Setting radius to 0.
# Invalid observation for source 2871 . Setting radius to 0.
# Invalid observation for source 2872 . Setting radius to 0.
# Invalid observation for source 2878 . Setting radius to 0.
# Invalid observation for source 2881 . Setting radius to 0.
# Invalid observation for source 2882 . Setting radius to 0.
# Invalid observation for source 2884 . Setting radius to 0.
# Invalid observation for source 2885 . Setting radius to 0.
# Invalid observation for source 2891 . Setting radius to 0.
# Invalid observation for source 2894 . Setting radius to 0.
# Invalid observation for source 2895 . Setting radius to 0.
# Invalid observation for source 2902 . Setting radius to 0.
# Invalid observation for source 2903 . Setting radius to 0.
# Invalid observation for source 2904 . Setting radius to 0.
# Invalid observation for source 2907 . Setting radius to 0.
# Invalid observation for source 2911 . Setting radius to 0.
# Invalid observation for source 2913 . Setting radius to 0.
# Invalid observation for source 2915 . Setting radius to 0.
# Invalid observation for source 2916 . Setting radius to 0.
# Invalid observation for source 2919 . Setting radius to 0.
# Invalid observation for source 2923 . Setting radius to 0.
# Invalid observation for source 2925 . Setting radius to 0.
# Invalid observation for source 2933 . Setting radius to 0.
# Invalid observation for source 2934 . Setting radius to 0.
# Invalid observation for source 2935 . Setting radius to 0.
# Invalid observation for source 2937 . Setting radius to 0.
# Invalid observation for source 2938 . Setting radius to 0.
# Invalid observation for source 2941 . Setting radius to 0.
# Invalid observation for source 2943 . Setting radius to 0.
# Invalid observation for source 2944 . Setting radius to 0.
# Invalid observation for source 2945 . Setting radius to 0.
# Invalid observation for source 2946 . Setting radius to 0.
# Invalid observation for source 2948 . Setting radius to 0.
# Invalid observation for source 2949 . Setting radius to 0.
# Invalid observation for source 2951 . Setting radius to 0.
# Invalid observation for source 2954 . Setting radius to 0.
# Invalid observation for source 2957 . Setting radius to 0.
# Invalid observation for source 2958 . Setting radius to 0.
# Invalid observation for source 2959 . Setting radius to 0.
# Invalid observation for source 2960 . Setting radius to 0.
# Invalid observation for source 2961 . Setting radius to 0.
# Invalid observation for source 2967 . Setting radius to 0.
# Invalid observation for source 2968 . Setting radius to 0.
# Invalid observation for source 2971 . Setting radius to 0.
# Invalid observation for source 2972 . Setting radius to 0.
# Invalid observation for source 2973 . Setting radius to 0.
# Invalid observation for source 2974 . Setting radius to 0.
# Invalid observation for source 2975 . Setting radius to 0.
# Invalid observation for source 2977 . Setting radius to 0.
# Invalid observation for source 2979 . Setting radius to 0.
# Invalid observation for source 2982 . Setting radius to 0.
# Invalid observation for source 2992 . Setting radius to 0.
# Invalid observation for source 2993 . Setting radius to 0.
# Invalid observation for source 2994 . Setting radius to 0.
# Invalid observation for source 2995 . Setting radius to 0.
# Invalid observation for source 2997 . Setting radius to 0.
# Invalid observation for source 2999 . Setting radius to 0.
# Invalid observation for source 3000 . Setting radius to 0.
# Invalid observation for source 3001 . Setting radius to 0.
# Invalid observation for source 3002 . Setting radius to 0.
# Invalid observation for source 3004 . Setting radius to 0.
# Invalid observation for source 3005 . Setting radius to 0.
# Invalid observation for source 3006 . Setting radius to 0.
# Invalid observation for source 3007 . Setting radius to 0.
# Invalid observation for source 3009 . Setting radius to 0.
# Invalid observation for source 3027 . Setting radius to 0.
# Invalid observation for source 3028 . Setting radius to 0.
# Invalid observation for source 3029 . Setting radius to 0.
# Invalid observation for source 3030 . Setting radius to 0.
# Invalid observation for source 3031 . Setting radius to 0.
# Invalid observation for source 3039 . Setting radius to 0.
# Invalid observation for source 3041 . Setting radius to 0.
# Invalid observation for source 3042 . Setting radius to 0.
# Invalid observation for source 3043 . Setting radius to 0.
# Invalid observation for source 3044 . Setting radius to 0.
# Invalid observation for source 3053 . Setting radius to 0.
# Invalid observation for source 3054 . Setting radius to 0.
# Invalid observation for source 3055 . Setting radius to 0.
# Invalid observation for source 3061 . Setting radius to 0.
# Invalid observation for source 3064 . Setting radius to 0.
# Invalid observation for source 3073 . Setting radius to 0.
# Invalid observation for source 3078 . Setting radius to 0.
# Invalid observation for source 3080 . Setting radius to 0.
# Invalid observation for source 3088 . Setting radius to 0.
# Invalid observation for source 3090 . Setting radius to 0.
# Invalid observation for source 3091 . Setting radius to 0.
# Invalid observation for source 3092 . Setting radius to 0.
# Invalid observation for source 3093 . Setting radius to 0.
# Invalid observation for source 3094 . Setting radius to 0.
# Invalid observation for source 3095 . Setting radius to 0.
# Invalid observation for source 3107 . Setting radius to 0.
# Invalid observation for source 3109 . Setting radius to 0.
# Invalid observation for source 3110 . Setting radius to 0.
# Invalid observation for source 3111 . Setting radius to 0.
# Invalid observation for source 3113 . Setting radius to 0.
# Invalid observation for source 3114 . Setting radius to 0.
# Invalid observation for source 3115 . Setting radius to 0.
# Invalid observation for source 3116 . Setting radius to 0.
# Invalid observation for source 3117 . Setting radius to 0.
# Invalid observation for source 3118 . Setting radius to 0.
# Invalid observation for source 3122 . Setting radius to 0.
# Invalid observation for source 3123 . Setting radius to 0.
# Invalid observation for source 3124 . Setting radius to 0.
# Invalid observation for source 3125 . Setting radius to 0.
# Invalid observation for source 3126 . Setting radius to 0.
# Invalid observation for source 3128 . Setting radius to 0.
# Invalid observation for source 3129 . Setting radius to 0.
# Invalid observation for source 3130 . Setting radius to 0.
# Invalid observation for source 3131 . Setting radius to 0.
# Invalid observation for source 3133 . Setting radius to 0.
# Invalid observation for source 3135 . Setting radius to 0.
# Invalid observation for source 3137 . Setting radius to 0.
# Invalid observation for source 3138 . Setting radius to 0.
# Invalid observation for source 3139 . Setting radius to 0.
# Invalid observation for source 3140 . Setting radius to 0.
# Invalid observation for source 3147 . Setting radius to 0.
# Invalid observation for source 3148 . Setting radius to 0.
# Invalid observation for source 3150 . Setting radius to 0.
# Invalid observation for source 3157 . Setting radius to 0.
# Invalid observation for source 3160 . Setting radius to 0.
# Invalid observation for source 3164 . Setting radius to 0.
# Invalid observation for source 3165 . Setting radius to 0.
# Invalid observation for source 3169 . Setting radius to 0.
# Invalid observation for source 3170 . Setting radius to 0.
# Invalid observation for source 3173 . Setting radius to 0.
# Invalid observation for source 3176 . Setting radius to 0.
# Invalid observation for source 3177 . Setting radius to 0.
# Invalid observation for source 3178 . Setting radius to 0.
# Invalid observation for source 3179 . Setting radius to 0.
# Invalid observation for source 3182 . Setting radius to 0.
# Invalid observation for source 3191 . Setting radius to 0.
# Invalid observation for source 3193 . Setting radius to 0.
# Invalid observation for source 3195 . Setting radius to 0.
# Invalid observation for source 3200 . Setting radius to 0.
# Invalid observation for source 3201 . Setting radius to 0.
# Invalid observation for source 3202 . Setting radius to 0.
# Invalid observation for source 3203 . Setting radius to 0.
# Invalid observation for source 3206 . Setting radius to 0.
# Invalid observation for source 3207 . Setting radius to 0.
# Invalid observation for source 3208 . Setting radius to 0.
# Invalid observation for source 3209 . Setting radius to 0.
# Invalid observation for source 3210 . Setting radius to 0.
# Invalid observation for source 3223 . Setting radius to 0.
# Invalid observation for source 3225 . Setting radius to 0.
# Invalid observation for source 3226 . Setting radius to 0.
# Invalid observation for source 3227 . Setting radius to 0.
# Invalid observation for source 3241 . Setting radius to 0.
# Invalid observation for source 3242 . Setting radius to 0.
# Invalid observation for source 3243 . Setting radius to 0.
# Invalid observation for source 3244 . Setting radius to 0.
# Invalid observation for source 3245 . Setting radius to 0.
# Invalid observation for source 3248 . Setting radius to 0.
# Invalid observation for source 3249 . Setting radius to 0.
# Invalid observation for source 3250 . Setting radius to 0.
# Invalid observation for source 3251 . Setting radius to 0.
# Invalid observation for source 3252 . Setting radius to 0.
# Invalid observation for source 3260 . Setting radius to 0.
# Invalid observation for source 3261 . Setting radius to 0.
# Invalid observation for source 3263 . Setting radius to 0.
# Invalid observation for source 3264 . Setting radius to 0.
# Invalid observation for source 3265 . Setting radius to 0.
# Invalid observation for source 3266 . Setting radius to 0.
# Invalid observation for source 3275 . Setting radius to 0.
# Invalid observation for source 3279 . Setting radius to 0.
# Invalid observation for source 3280 . Setting radius to 0.
# Invalid observation for source 3282 . Setting radius to 0.
# Invalid observation for source 3283 . Setting radius to 0.
# Invalid observation for source 3284 . Setting radius to 0.
# Invalid observation for source 3285 . Setting radius to 0.
# Invalid observation for source 3287 . Setting radius to 0.
# Invalid observation for source 3288 . Setting radius to 0.
# Invalid observation for source 3289 . Setting radius to 0.
# Invalid observation for source 3293 . Setting radius to 0.
# Invalid observation for source 3296 . Setting radius to 0.
# Invalid observation for source 3300 . Setting radius to 0.
# Invalid observation for source 3304 . Setting radius to 0.
# Invalid observation for source 3305 . Setting radius to 0.
# Invalid observation for source 3306 . Setting radius to 0.
# Invalid observation for source 3307 . Setting radius to 0.
# Invalid observation for source 3308 . Setting radius to 0.
# Invalid observation for source 3310 . Setting radius to 0.
# Invalid observation for source 3313 . Setting radius to 0.
# Invalid observation for source 3314 . Setting radius to 0.
# Invalid observation for source 3315 . Setting radius to 0.
# Invalid observation for source 3316 . Setting radius to 0.
# Invalid observation for source 3317 . Setting radius to 0.
# Invalid observation for source 3320 . Setting radius to 0.
# Invalid observation for source 3322 . Setting radius to 0.
# Invalid observation for source 3323 . Setting radius to 0.
# Invalid observation for source 3324 . Setting radius to 0.
# Invalid observation for source 3328 . Setting radius to 0.
# Invalid observation for source 3329 . Setting radius to 0.
# Invalid observation for source 3338 . Setting radius to 0.
# Invalid observation for source 3339 . Setting radius to 0.
# Invalid observation for source 3351 . Setting radius to 0.
# Invalid observation for source 3352 . Setting radius to 0.
# Invalid observation for source 3353 . Setting radius to 0.
# Invalid observation for source 3364 . Setting radius to 0.
# Invalid observation for source 3368 . Setting radius to 0.
# Invalid observation for source 3369 . Setting radius to 0.
# Invalid observation for source 3373 . Setting radius to 0.
# Invalid observation for source 3379 . Setting radius to 0.
# Invalid observation for source 3380 . Setting radius to 0.
# Invalid observation for source 3390 . Setting radius to 0.
# Invalid observation for source 3391 . Setting radius to 0.
# Invalid observation for source 3392 . Setting radius to 0.
# Invalid observation for source 3394 . Setting radius to 0.
# Invalid observation for source 3396 . Setting radius to 0.
# Invalid observation for source 3401 . Setting radius to 0.
# Invalid observation for source 3408 . Setting radius to 0.
# Invalid observation for source 3410 . Setting radius to 0.
# Invalid observation for source 3415 . Setting radius to 0.
# Invalid observation for source 3416 . Setting radius to 0.
# Invalid observation for source 3417 . Setting radius to 0.
# Invalid observation for source 3426 . Setting radius to 0.
# Invalid observation for source 3430 . Setting radius to 0.
# Invalid observation for source 3432 . Setting radius to 0.
# Invalid observation for source 3433 . Setting radius to 0.
# Invalid observation for source 3444 . Setting radius to 0.
# Invalid observation for source 3446 . Setting radius to 0.
# Invalid observation for source 3447 . Setting radius to 0.
# Invalid observation for source 3451 . Setting radius to 0.
# Invalid observation for source 3456 . Setting radius to 0.
# Invalid observation for source 3457 . Setting radius to 0.
# Invalid observation for source 3458 . Setting radius to 0.
# Invalid observation for source 3459 . Setting radius to 0.
# Invalid observation for source 3462 . Setting radius to 0.
# Invalid observation for source 3469 . Setting radius to 0.
# Invalid observation for source 3471 . Setting radius to 0.
# Invalid observation for source 3473 . Setting radius to 0.
# Invalid observation for source 3474 . Setting radius to 0.
# Invalid observation for source 3476 . Setting radius to 0.
# Invalid observation for source 3478 . Setting radius to 0.
# Invalid observation for source 3479 . Setting radius to 0.
# Invalid observation for source 3484 . Setting radius to 0.
# Invalid observation for source 3485 . Setting radius to 0.
# Invalid observation for source 3486 . Setting radius to 0.
# Invalid observation for source 3487 . Setting radius to 0.
# Invalid observation for source 3488 . Setting radius to 0.
# Invalid observation for source 3490 . Setting radius to 0.

# %% [markdown]
# `CalcPU` calculates the total 1- and 2-$\sigma$ positional uncertainty from both the X-ray data and the input standard deviations on the astrometric correction. This can be saved directly into to your `DataFrame`:

# %%
import pandas as pd

M101_CSC['1Sig'] = sig1
M101_CSC['2Sig'] = sig2
display(M101_CSC)

M101_CSC.to_csv('M101_csc_astrocorrected.frame')
# Out:
#       Separation                 CSC ID          RA        Dec        ExpTime  \
# 0       0.835778  2CXO J140312.5+542056  210.802227  54.348952  192658.710333
# 1       0.835778  2CXO J140312.5+542056  210.802227  54.348952  142729.493705
# 2       0.835778  2CXO J140312.5+542056  210.802227  54.348952  141298.623812
# 3       0.835778  2CXO J140312.5+542056  210.802227  54.348952  132129.439441
# 4       0.835778  2CXO J140312.5+542056  210.802227  54.348952  130186.649966
# ...          ...                    ...         ...        ...            ...
# 3487  892.520732  2CXO J140447.2+542633  211.196627  54.442543  120993.038017
# 3488  892.520732  2CXO J140447.2+542633  211.196627  54.442543   88598.047743
# 3489  892.520732  2CXO J140447.2+542633  211.196627  54.442543   81021.851289
# 3490  892.520732  2CXO J140447.2+542633  211.196627  54.442543   52087.100775
# 3491  892.520732  2CXO J140447.2+542633  211.196627  54.442543   14276.493764
#
#           Theta  Err Ellipse Major  Err Ellipse Minor  Err Ellipse Angle  \
# 0      2.687974           0.296164           0.295254          89.606978
# 1      2.727056           0.296164           0.295254          89.606978
# 2      2.783596           0.296164           0.295254          89.606978
# 3      2.690653           0.296164           0.295254          89.606978
# 4      2.749161           0.296164           0.295254          89.606978
# ...         ...                ...                ...                ...
# 3487        NaN           1.612100           0.795238          86.007749
# 3488        NaN           1.612100           0.795238          86.007749
# 3489  13.486809           1.612100           0.795238          86.007749
# 3490        NaN           1.612100           0.795238          86.007749
# 3491   3.416463           1.612100           0.795238          86.007749
#
#       Significance  ... HM Ratio lolim HM Ratio hilim  MS Ratio  \
# 0        22.302136  ...      -0.100562       0.156777 -0.553404
# 1        22.302136  ...      -0.100562       0.156777 -0.553404
# 2        22.302136  ...      -0.100562       0.156777 -0.553404
# 3        22.302136  ...      -0.100562       0.156777 -0.553404
# 4        22.302136  ...      -0.100562       0.156777 -0.553404
# ...            ...  ...            ...            ...       ...
# 3487      2.650000  ...            NaN            NaN       NaN
# 3488      2.650000  ...            NaN            NaN       NaN
# 3489      2.650000  ...            NaN            NaN       NaN
# 3490      2.650000  ...            NaN            NaN       NaN
# 3491      2.650000  ...            NaN            NaN       NaN
#
#       MS Ratio lolim  MS Ratio hilim      Counts  Counts lolim  Counts hilim  \
# 0           -0.61649       -0.485322  170.006026    155.698239    184.313814
# 1           -0.61649       -0.485322  254.489381    233.532285    274.136658
# 2           -0.61649       -0.485322  442.576953    419.112035    464.477543
# 3           -0.61649       -0.485322  131.798703    118.539780    144.321019
# 4           -0.61649       -0.485322  649.590529    616.129127    683.051932
# ...              ...             ...         ...           ...           ...
# 3487             NaN             NaN    0.000000      0.000000     59.364933
# 3488             NaN             NaN    0.000000      0.000000     14.952548
# 3489             NaN             NaN   53.481053     29.414579     77.547526
# 3490             NaN             NaN    0.000000      0.000000     34.780341
# 3491             NaN             NaN    7.591890      4.313574     10.870206
#
#           1Sig      2Sig
# 0     0.499641  1.003207
# 1     0.498084  0.999338
# 2     0.496277  0.994895
# 3     0.502819  1.014894
# 4     0.494942  0.991738
# ...        ...       ...
# 3487  0.487466  0.974933
# 3488  0.487466  0.974933
# 3489  3.190131  7.658538
# 3490  0.487466  0.974933
# 3491  0.738103  1.710737
#
# [3492 rows x 30 columns]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 7
#       4 M101_CSC['2Sig'] = sig2
#       5 display(M101_CSC)
# ----> 7 M101_CSC.to_csv('testdata/M101_csc_astrocorrected.frame')
#
# File ~/anaconda3/envs/jupyterbook/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/jupyterbook/lib/python3.12/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/anaconda3/envs/jupyterbook/lib/python3.12/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/anaconda3/envs/jupyterbook/lib/python3.12/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/anaconda3/envs/jupyterbook/lib/python3.12/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/anaconda3/envs/jupyterbook/lib/python3.12/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'testdata'

# %% [markdown]
# Depending on what information you chose to pull from `CSCview`, you may see that some sources have multiple observations listed in your DataFrame. These different observations may have different 2-$\sigma$ radii associated with them. To get the best localization of each X-ray source, we should select the observation with the smallest 2-$\sigma$. I use the code below to select what I think is likely the best observation:

# %%
ids = FindUnique(M101_CSC, header="CSC ID")["CSC ID"].values.tolist()
M101_best = BuildFrame()

for i in ids: 
    # Search for all instances of each source
    Temp = Find(M101_CSC, "CSC ID = " + i)
    
    # If none of the events have a valid count, try to avoid sources where counts = NaN
    if len(Find(Temp, ["Counts != NaN", "Theta != NaN"])) > 0: 
        Temp = Find(Temp, ["Counts != NaN", "Theta != NaN"])
    
    # Specifically focus on those with a valid number of counts
    if len(Find(Temp, "Counts > 0")) > 0: 
        Temp = Find(Temp, ["Counts > 0"])
        
    # Otherwise, all instances with counts = 0 have the same measurements, so it doesn't matter
    else: pass;
    
    # Take the source with the smallest 2sig. If there's more than one, take the first on the list.
    Tempbest = Find(Temp, "2Sig =< " + str(min(Temp["2Sig"]))).iloc[:1]
    
    # Add the chosen source observation to the new DataFrame
    M101_best = pd.concat([M101_best, Tempbest], ignore_index=True)

# Saving results to a DataFrame file
M101_best.to_csv("M101_csc_bestrads.frame")

display(M101_best)
# Out:
#      Separation                 CSC ID          RA        Dec        ExpTime  \
# 0      0.835778  2CXO J140312.5+542056  210.802227  54.348952   98379.672624
# 1      1.951564  2CXO J140312.7+542055  210.803345  54.348663   49085.676020
# 2      2.480949  2CXO J140312.5+542053  210.802221  54.348072   98379.672624
# 3      5.227586  2CXO J140313.1+542052  210.804553  54.347994  132129.439441
# 4      9.124404  2CXO J140313.5+542053  210.806667  54.348188   98379.672624
# ..          ...                    ...         ...        ...            ...
# 550  883.411465  2CXO J140138.8+541527  210.411860  54.257747  132129.439441
# 551  884.529187  2CXO J140450.6+541721  211.211172  54.289330  139822.610581
# 552  886.380054  2CXO J140216.3+543313  210.567813  54.553731  131222.705704
# 553  890.405834  2CXO J140445.4+541452  211.189426  54.247897  139819.410649
# 554  892.520732  2CXO J140447.2+542633  211.196627  54.442543   14276.493764
#
#          Theta  Err Ellipse Major  Err Ellipse Minor  Err Ellipse Angle  \
# 0     1.280763           0.296164           0.295254          89.606978
# 1     4.725025           0.548072           0.380093          86.863933
# 2     1.321652           0.296164           0.295733          84.016491
# 3     2.762119           0.880650           0.578584          29.467809
# 4     1.410741           0.633314           0.466131          58.539300
# ..         ...                ...                ...                ...
# 550  12.087047           8.647887           6.103176         111.468541
# 551   9.951487           1.357801           1.057531          95.305118
# 552  13.887674           2.480733           2.445301         115.654637
# 553  10.703677           4.581313           2.651713         135.472019
# 554   3.416463           1.612100           0.795238          86.007749
#
#      Significance  ... HM Ratio lolim HM Ratio hilim  MS Ratio  \
# 0       22.302136  ...      -0.100562       0.156777 -0.553404
# 1        2.648649  ...      -0.080575       1.000000 -0.999375
# 2       19.554042  ...       0.026858       0.158026 -0.316052
# 3        3.421053  ...       0.130543       0.906309 -0.868207
# 4        1.739130  ...       0.194254       1.000000 -0.999375
# ..            ...  ...            ...            ...       ...
# 550      4.277778  ...      -0.113054       0.935041 -0.792005
# 551      8.976584  ...      -0.099313       0.204247 -0.374766
# 552      6.783292  ...      -0.025609       0.271705 -0.222361
# 553      4.411765  ...       0.005621       0.434104  0.999375
# 554      2.650000  ...            NaN            NaN       NaN
#
#      MS Ratio lolim  MS Ratio hilim      Counts  Counts lolim  Counts hilim  \
# 0         -0.616490       -0.485322  234.492581    216.678502    252.306660
# 1         -1.000000       -0.715178  209.970149    192.843759    227.096539
# 2         -0.364147       -0.265459  252.846172    234.295673    271.396671
# 3         -0.973766       -0.718926   23.229213     16.216620     30.241806
# 4         -1.000000       -0.370394    7.040343      2.992146     11.088540
# ..              ...             ...         ...           ...           ...
# 550       -0.932542       -0.617739   76.034629     52.273807     99.795450
# 551       -0.472829       -0.270456  155.562531    135.448493    174.718757
# 552       -0.322923       -0.118051  149.738677    121.454705    176.358886
# 553        0.501562        1.000000         NaN           NaN           NaN
# 554             NaN             NaN    7.591890      4.313574     10.870206
#
#          1Sig      2Sig
# 0    0.493011  0.988256
# 1    0.516471  1.038077
# 2    0.492957  0.988086
# 3    0.561749  1.188360
# 4    0.593981  1.300029
# ..        ...       ...
# 550  1.921653  4.517698
# 551  0.793067  1.558488
# 552  1.676834  3.103807
# 553  0.487466  0.974933
# 554  0.738103  1.710737
#
# [555 rows x 30 columns]

# %% [markdown]
# You now have the RA and Dec of each source (ideally updated based on the results from your astrometric correction) and the best positional uncertainty radii of each one. Save these radii as region files that can be plotted over the *HST* image in `DS9` using `WriteScript.WriteReg()`:

# %%
# Saving the 1 and 2 sigma region files for DS9 use.
# The 2sig region files have the CSC ID printed above each source.
WriteReg(M101_best, radius=M101_best['2Sig'].values.tolist(), radunit='arcsec', \
         idname="CSC ID", showlabel=True, outfile='M101_bestrads_2sig.reg')
WriteReg(M101_best, radius=M101_best['1Sig'].values.tolist(), radunit='arcsec', \
         outfile='M101_bestrads_1sig.reg')
# Out:
# Saving M101_bestrads_2sig.reg
# Saving M101_bestrads_1sig.reg

# %% [markdown]
# Now when you plot these region files on your *HST* image in `DS9`, you will see *exactly* where each XRB is expected to be found and which optical sources are associated with them. From here, we can get into the optical analysis, including: selecting the correct optical counterpart, extracting their photometric properties, and comparing those properties to theoretical models to estimate the donor star mass!

# %% [markdown]
# ```{figure} ../images/positional_uncertainties.png
# :name: fig-positional-uncertainties
# :width: 750px
#
# Examples of the 1- and 2-$\sigma$ positional uncertainties of *CXO* sources on an *HST* image, after applying the astrometric correction. By eye, the central source is clearly associated with a background galaxy, while the others are likely genuine XRBs.
# ```
